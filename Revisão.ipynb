# %% [markdown]
# <a href="https://colab.research.google.com/github/Renan023/revisao-e-treino/blob/main/Revis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import seaborn as sns 
from sklearn import datasets,svm
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e9fd461e-488c-4fd0-b14b-7cd34ebc3371" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9fd461e-488c-4fd0-b14b-7cd34ebc3371">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
list = {'faculdade':['FMU','Faculdade descomplica','São Camilo'],'Cursos':['Ed. Física','Análise e desenvolvimemto de sistemas','Fisioterapia']}

# %%
fac = pd.DataFrame(list,columns=['faculdade','Cursos'])

# %%
fac
# Out:
#                faculdade                                 Cursos
# 0                    FMU                             Ed. Física
# 1  Faculdade descomplica  Análise e desenvolvimemto de sistemas
# 2             São Camilo                           Fisioterapia

# %%
iris = datasets.load_iris()
x = iris.data
y = iris. target

# %%
arq = pd.read_excel('Estados.xlsx')
arq1 = pd.read_excel('Estados_SE.xlsx')

irs = pd.DataFrame(x,columns=iris.feature_names)

analise = pd.read_excel('AdventureWorks.xlsx')

# %%
irs['target'] = pd.Categorical.from_codes(y, iris.target_names)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
dfx = pd.DataFrame(x,columns=['sepal length (cm)',
 'sepal width (cm)',
 'petal length (cm)',
 'petal width (cm)'])
dfy = pd.DataFrame(y, columns=['target'])

# %%
files = pd.concat([arq,arq1],ignore_index=True)

iris = pd.concat([dfx,dfy],axis=1.0)

# %%
sns.pairplot(irs,hue='target')

# %%
del files ['Sintaxe']

# %%
files
# Out:
#     IBGE               Estado  UF               Região  Qtd Mun
# 0     11             Rondônia  RO         Região Norte       52
# 1     12                 Acre  AC         Região Norte       22
# 2     13             Amazonas  AM         Região Norte       62
# 3     14              Roraima  RR         Região Norte       15
# 4     15                 Pará  PA         Região Norte      144
# 5     16                Amapá  AP         Região Norte       16
# 6     17            Tocantins  TO         Região Norte      139
# 7     21             Maranhão  MA      Região Nordeste      217
# 8     22                Piauí  PI      Região Nordeste      224
# 9     23                Ceará  CE      Região Nordeste      184
# 10    24  Rio Grande do Norte  RN      Região Nordeste      167
# 11    25              Paraíba  PB      Região Nordeste      223
# 12    26           Pernambuco  PE      Região Nordeste      185
# 13    27              Alagoas  AL      Região Nordeste      102
# ...

# %%
del files ['Qtd']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Qtd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
analise.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
analise.rename(columns={'Quantidade':'Qtdade'},inplace=True)

# %%
files.sort_values(['Estado'],inplace=True)

# %%
files
# Out:
#     IBGE               Estado  UF               Região  Qtd Mun
# 1     12                 Acre  AC         Região Norte       22
# 13    27              Alagoas  AL      Região Nordeste      102
# 5     16                Amapá  AP         Região Norte       16
# 2     13             Amazonas  AM         Região Norte       62
# 15    29                Bahia  BA      Região Nordeste      417
# 9     23                Ceará  CE      Região Nordeste      184
# 26    53     Distrito Federal  DF  Região Centro-Oeste        1
# 28    32       Espírito Santo  ES       Região Sudeste       78
# 17    32       Espírito Santo  ES       Região Sudeste       78
# 25    52                Goiás  GO  Região Centro-Oeste      246
# 7     21             Maranhão  MA      Região Nordeste      217
# 24    51          Mato Grosso  MT  Região Centro-Oeste      141
# 23    50   Mato Grosso do Sul  MS  Região Centro-Oeste       79
# 16    31         Minas Gerais  MG       Região Sudeste      853
# ...

# %%
regiao = pd.read_excel('procv.xlsx','Regiao')
pop = pd.read_excel('procv.xlsx','Populacao')

# %%
left = pd.merge(regiao,pop,left_on=['Cidade','Estado'],right_on=['Cidade','Estado'],how='left')
right = pd.merge(regiao,pop,left_on=['Cidade','Estado'],right_on=['Cidade','Estado'],how='right')
inner = pd.merge(regiao,pop,left_on=['Cidade','Estado'],right_on=['Cidade','Estado'],how='inner')
outer = pd.merge(regiao,pop,left_on=['Cidade','Estado'],right_on=['Cidade','Estado'],how='outer')

# %%
right
# Out:
#            Cidade Estado        Regiao  Populacao
# 0         Aracaju     SE           NaN     571149
# 1           Belem     PA         Norte    1393399
# 2  Belo Horizonte     MG           NaN    2375151
# 3    Campo Grande     MS  Centro Oeste     786797
# 4        Curitiba     PR           Sul    1751907
# 5           Natal     RN      Nordeste     803739
# 6    Porto Alegre     RS           Sul    1409351
# 7  Rio de Janeiro     RJ       Sudeste    6320446
# 8        Salvador     BA      Nordeste    2675656
# 9       São Paulo     SP       Sudeste   11253503

# %%
left
# Out:
#            Cidade Estado        Regiao   Populacao
# 0           Belem     PA         Norte   1393399.0
# 1    Campo Grande     MS  Centro Oeste    786797.0
# 2        Curitiba     PR           Sul   1751907.0
# 3         Goiania     GO  Centro Oeste         NaN
# 4          Manaus     AM         Norte         NaN
# 5           Natal     RN      Nordeste    803739.0
# 6    Porto Alegre     RS           Sul   1409351.0
# 7  Rio de Janeiro     RJ       Sudeste   6320446.0
# 8        Salvador     BA      Nordeste   2675656.0
# 9       São Paulo     SP       Sudeste  11253503.0

# %%
inner
# Out:
#            Cidade Estado        Regiao  Populacao
# 0           Belem     PA         Norte    1393399
# 1    Campo Grande     MS  Centro Oeste     786797
# 2        Curitiba     PR           Sul    1751907
# 3           Natal     RN      Nordeste     803739
# 4    Porto Alegre     RS           Sul    1409351
# 5  Rio de Janeiro     RJ       Sudeste    6320446
# 6        Salvador     BA      Nordeste    2675656
# 7       São Paulo     SP       Sudeste   11253503

# %%
outer
# Out:
#             Cidade Estado        Regiao   Populacao
# 0            Belem     PA         Norte   1393399.0
# 1     Campo Grande     MS  Centro Oeste    786797.0
# 2         Curitiba     PR           Sul   1751907.0
# 3          Goiania     GO  Centro Oeste         NaN
# 4           Manaus     AM         Norte         NaN
# 5            Natal     RN      Nordeste    803739.0
# 6     Porto Alegre     RS           Sul   1409351.0
# 7   Rio de Janeiro     RJ       Sudeste   6320446.0
# 8         Salvador     BA      Nordeste   2675656.0
# 9        São Paulo     SP       Sudeste  11253503.0
# 10         Aracaju     SE           NaN    571149.0
# 11  Belo Horizonte     MG           NaN   2375151.0

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.10,random_state=60)

# %%
clf = svm.SVC(kernel='linear',C=1.0)

# %%
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(x_train)

# %%
print(classification_report(y_train,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        44
#            1       1.00      0.98      0.99        44
#            2       0.98      1.00      0.99        47
#
#     accuracy                           0.99       135
#    macro avg       0.99      0.99      0.99       135
# weighted avg       0.99      0.99      0.99       135

# %%
clf = KNeighborsClassifier(n_neighbors=10)

# %%
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
confusion_matrix(y_train,y_pred)
# Out:
# array([[44,  0,  0],
#        [ 0, 43,  1],
#        [ 0,  0, 47]])

# %%
analise.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Qtdade                     int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
analise['ID Loja'] = analise['ID Loja'].astype('object')

# %%
analise['ID Cliente'] = analise['ID Cliente'].astype('object')
analise['ID Produto'] = analise['ID Produto'].astype('object')

# %%
analise.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                   object
# ID Produto                object
# ID Cliente                object
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Qtdade                     int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
analise['Valor total'] = analise['Qtdade']*analise['Preço Unitário']

# %%
analise['Tempo de Entrega']= (analise['Data Envio']-analise['Data Venda']).dt.days

# %%
analise['Lucro'] = analise['Preço Unitário']-analise['Custo Unitário']

# %%
analise.rename(columns={'Lucro':'Lucro Unitário'},inplace=True)

# %%
del analise ['Custo total']

# %%
analise['Custo total'] = analise['Custo Unitário']*analise['Qtdade']

# %%
analise
# Out:
#     Data Venda Data Envio ID Loja ID Produto ID Cliente       No. Venda  \
# 0   2008-05-09 2008-05-29     199        384      18839  200805093CS607
# 1   2008-05-12 2008-05-17     306        384      19051  200805123CS567
# 2   2008-05-14 2008-05-20     306        384      19052  200805143CS576
# 3   2008-05-21 2008-05-27     306        384      19052  200805213CS576
# 4   2008-06-20 2008-06-27     306        384      19053  200806203CS586
# ..         ...        ...     ...        ...        ...             ...
# 899 2008-03-22 2008-04-04     306       1226      19049  200803224CS555
# 900 2008-10-04 2008-10-15     306       1155      19057  200810044CS636
# 901 2008-12-11 2008-12-15     306       1155      19060  200812114CS676
# 902 2008-12-17 2008-12-21     306       1226      19060  200812174CS676
# 903 2008-12-21 2008-12-25     306       1155      19060  200812214CS676
#
#      Custo Unitário  Preço Unitário  Qtdade  Valor Desconto  Valor Venda  \
# ...

# %%
analise['Lucro total'] = analise['Valor total']-analise['Custo total']

# %%
analise.groupby([analise['Data Envio'].dt.month,'Marca'])['Lucro total'].sum().plot.bar()

# %%
analise['Custo Unitário'].sum()
# Out:
# 245893.55999999997

# %%
analise['Lucro total'].mean()
# Out:
# 4558.396626106194

# %%
analise['Custo total'].min()
# Out:
# 81.44

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
analise.groupby([analise['Data Venda'].dt.year,'Marca'])['Custo Unitário'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works              35,903.74
#             Contoso                         407.20
#             Fabrikam                     93,853.59
# 2009        Adventure Works              47,058.30
#             Contoso                         468.28
#             Fabrikam                     68,202.45
# Name: Custo Unitário, dtype: float64

# %%
analise.groupby(analise['Data Envio'].dt.month)['Lucro total'].sum().plot.bar();
