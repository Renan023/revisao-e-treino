# %% [markdown]
# <a href="https://colab.research.google.com/github/Renan023/revisao-e-treino/blob/main/revis_o_com_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   
from google.colab import files
files.upload()

# %%
arq = pd.read_excel('Estados.xlsx')
arq1 = pd.read_excel('Estados_SE.xlsx')

# %%
files =pd.concat([arq,arq1],ignore_index=True)

# %%
files
# Out:
#     IBGE               Estado  UF               Região  Qtd Mun Sintaxe
# 0     11             Rondônia  RO         Região Norte       52  11'RO'
# 1     12                 Acre  AC         Região Norte       22  12'AC'
# 2     13             Amazonas  AM         Região Norte       62  13'AM'
# 3     14              Roraima  RR         Região Norte       15  14'RR'
# 4     15                 Pará  PA         Região Norte      144  15'PA'
# 5     16                Amapá  AP         Região Norte       16  16'AP'
# 6     17            Tocantins  TO         Região Norte      139  17'TO'
# 7     21             Maranhão  MA      Região Nordeste      217  21'MA'
# 8     22                Piauí  PI      Região Nordeste      224  22'PI'
# 9     23                Ceará  CE      Região Nordeste      184  23'CE'
# 10    24  Rio Grande do Norte  RN      Região Nordeste      167  24'RN'
# 11    25              Paraíba  PB      Região Nordeste      223  25'PB'
# ...

# %%
del files ['Sintaxe']

# %%
files.dtypes
# Out:
# IBGE        int64
# Estado     object
# UF         object
# Região     object
# Qtd Mun     int64
# dtype: object

# %%
files.head()
# Out:
#    IBGE    Estado  UF        Região  Qtd Mun
# 0    11  Rondônia  RO  Região Norte       52
# 1    12      Acre  AC  Região Norte       22
# 2    13  Amazonas  AM  Região Norte       62
# 3    14   Roraima  RR  Região Norte       15
# 4    15      Pará  PA  Região Norte      144

# %%
files.sort_values(['Estado'],inplace=True)

# %%
files
# Out:
#     IBGE               Estado  UF               Região  Qtd Mun
# 1     12                 Acre  AC         Região Norte       22
# 13    27              Alagoas  AL      Região Nordeste      102
# 5     16                Amapá  AP         Região Norte       16
# 2     13             Amazonas  AM         Região Norte       62
# 15    29                Bahia  BA      Região Nordeste      417
# 9     23                Ceará  CE      Região Nordeste      184
# 26    53     Distrito Federal  DF  Região Centro-Oeste        1
# 28    32       Espírito Santo  ES       Região Sudeste       78
# 17    32       Espírito Santo  ES       Região Sudeste       78
# 25    52                Goiás  GO  Região Centro-Oeste      246
# 7     21             Maranhão  MA      Região Nordeste      217
# 24    51          Mato Grosso  MT  Região Centro-Oeste      141
# 23    50   Mato Grosso do Sul  MS  Região Centro-Oeste       79
# 16    31         Minas Gerais  MG       Região Sudeste      853
# ...

# %%
files.groupby([files['Estado'],'Região'])['Qtd Mun'].sum()
# Out:
# Estado               Região
# Acre                 Região Norte             22
# Alagoas              Região Nordeste         102
# Amapá                Região Norte             16
# Amazonas             Região Norte             62
# Bahia                Região Nordeste         417
# Ceará                Região Nordeste         184
# Distrito Federal     Região Centro-Oeste       1
# Espírito Santo       Região Sudeste          156
# Goiás                Região Centro-Oeste     246
# Maranhão             Região Nordeste         217
# Mato Grosso          Região Centro-Oeste     141
# Mato Grosso do Sul   Região Centro-Oeste      79
# Minas Gerais         Região Sudeste         1706
# Paraná               Região Sul              399
# Paraíba              Região Nordeste         223
# Pará                 Região Norte            144
# Pernambuco           Região Nordeste         185
# Piauí                Região Nordeste         224
# Rio Grande do Norte  Região Nordeste         167
# ...

# %%
files.groupby([files['Estado'],'Região'])['Qtd Mun'].sum().plot.bar();
